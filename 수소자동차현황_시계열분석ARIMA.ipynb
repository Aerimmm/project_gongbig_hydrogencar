# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import seaborn as sns # visualization library
import matplotlib.pyplot as plt # visualization library
from chart_studio import plotly as py #visualization library
from plotly.offline import init_notebook_mode, iplot # plotly offline mode
init_notebook_mode(connected=True) 
import plotly.graph_objs as go # plotly graphical object
import os
# import warnings library
import warnings        
# ignore filters
warnings.filterwarnings("ignore") # if there is a warning after some codes, this will avoid us to see them.
plt.style.use('ggplot') # style of plots. ggplot is one of the most used style, I also like it.
# Any results you write to the current directory are saved as output.
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.12.1.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
data = pd.read_csv('C:/Users/user/공공빅데이터_프로젝트/2019_2022_수소차_현황.csv', encoding = "euc-kr")

# %%
Hydr = pd.DataFrame(data)
Hydr.head()
# Out:
#          Date  Seoul  Busan  Daegu  Incheon  Gwangju  Daejeon  Ulsan  Sejong  \
# 0  2019-01-01     82      0      2        6      203        1    346       3
# 1  2019-02-01    105      4      2        6      203        1    345       3
# 2  2019-03-01    131      4      2        6      238        1    345       3
# 3  2019-04-01    143      8      4        6      304       19    530       3
# 4  2019-05-01    146     97      4        7      324       28    728       4
#
#    Gyunggi  Gangwon  Chuungbuk  Chuungnam  Jeonbuk  Jeonnam  Kyungbuk  \
# 0        8        0          0         61        2        1         0
# 1       10        0          0         61        2        1         0
# 2       18        0          0         61        1        1         0
# 3       38        0          0         62        1        2         1
# 4      103        0          2         89        1        3         2
#
#    Kyungnam  Jeju  Count
# 0       203     0    918
# 1       235     0    978
# 2       268     0   1079
# 3       321     0   1442
# 4       363     0   1901

# %%
Hydr.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 42 entries, 0 to 41
# Data columns (total 19 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Date    42 non-null     object
#  1   서울      42 non-null     object
#  2   부산      42 non-null     int64
#  3   대구      42 non-null     int64
#  4   인천      42 non-null     int64
#  5   광주      42 non-null     int64
#  6   대전      42 non-null     int64
#  7   울산      42 non-null     object
#  8   세종      42 non-null     int64
#  9   경기      42 non-null     object
#  10  강원      42 non-null     int64
#  11  충북      42 non-null     int64
#  12  충남      42 non-null     int64
#  13  전북      42 non-null     int64
#  14  전남      42 non-null     int64
#  15  경북      42 non-null     int64
#  16  경남      42 non-null     int64
#  17  제주      42 non-null     int64
#  18  Count   42 non-null     int64
# dtypes: int64(15), object(4)
# memory usage: 6.4+ KB

# %%
Hydr['Count'] = Hydr['Count'].astype(float, errors = 'raise')

# %%
Hydr["Date"] = pd.to_datetime(Hydr['Date'])

# %%
Hydr.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 42 entries, 0 to 41
# Data columns (total 19 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Date    42 non-null     datetime64[ns]
#  1   서울      42 non-null     object
#  2   부산      42 non-null     int64
#  3   대구      42 non-null     int64
#  4   인천      42 non-null     int64
#  5   광주      42 non-null     int64
#  6   대전      42 non-null     int64
#  7   울산      42 non-null     object
#  8   세종      42 non-null     int64
#  9   경기      42 non-null     object
#  10  강원      42 non-null     int64
#  11  충북      42 non-null     int64
#  12  충남      42 non-null     int64
#  13  전북      42 non-null     int64
#  14  전남      42 non-null     int64
#  15  경북      42 non-null     int64
#  16  경남      42 non-null     int64
#  17  제주      42 non-null     int64
#  18  Count   42 non-null     float64
# dtypes: datetime64[ns](1), float64(1), int64(14), object(3)
# memory usage: 6.4+ KB

# %%
Hydr.head()
# Out:
#         Date   서울  부산  대구  인천   광주  대전   울산  세종   경기  강원  충북  충남  전북  전남  경북  \
# 0 2019-01-01   82   0   2   6  203   1  346   3    8   0   0  61   2   1   0
# 1 2019-02-01  105   4   2   6  203   1  345   3   10   0   0  61   2   1   0
# 2 2019-03-01  131   4   2   6  238   1  345   3   18   0   0  61   1   1   0
# 3 2019-04-01  143   8   4   6  304  19  530   3   38   0   0  62   1   2   1
# 4 2019-05-01  146  97   4   7  324  28  728   4  103   0   2  89   1   3   2
#
#     경남  제주   Count
# 0  203   0   918.0
# 1  235   0   978.0
# 2  268   0  1079.0
# 3  321   0  1442.0
# 4  363   0  1901.0

# %%
Hydr.tail()
# Out:
#          Date    서울    부산   대구    인천    광주    대전    울산   세종    경기    강원    충북  \
# 37 2022-02-01  2443  1397  318  1071   964   872  2355  132  3634  1824   972
# 38 2022-03-01  2432  1434  322  1101   976   892  2387  142  3669  1857   993
# 39 2022-04-01  2435  1473  352  1139  1018  1045  2395  205  4004  1959  1095
# 40 2022-05-01  2583  1539  372  1189  1029  1156  2393  209  4430  2049  1170
# 41 2022-06-01  2665  1599  389  1246  1019  1172  2393  209  4733  2175  1246
#
#       충남    전북   전남   경북    경남  제주    Count
# 37   796  1350  364   56  1744   3  20295.0
# 38   836  1385  383   58  1812   4  20683.0
# 39   908  1435  448   77  1899   5  21892.0
# 40   990  1470  498   93  1955   4  23129.0
# 41  1048  1493  541  110  2075   6  24119.0

# %%
plt.figure(figsize = (22,8))
plt.plot(df.Date, df.Count)
plt.title("Hydrogen fueled car")
plt.xlabel("Date")
plt.ylabel("Count")
plt.show()

# %%
timeSeries = Hydr.loc[:, ["Date", "Count"]]
timeSeries.index = timeSeries.Date
ts = timeSeries.drop("Date", axis =1)
ts
# Out:
#               Count
# Date
# 2019-01-01    918.0
# 2019-02-01    978.0
# 2019-03-01   1079.0
# 2019-04-01   1442.0
# 2019-05-01   1901.0
# 2019-06-01   2353.0
# 2019-07-01   2774.0
# 2019-08-01   2955.0
# 2019-09-01   3436.0
# 2019-10-01   3951.0
# 2019-11-01   4650.0
# 2019-12-01   5083.0
# 2020-01-01   5167.0
# 2020-02-01   5558.0
# 2020-03-01   6125.0
# 2020-04-01   7033.0
# 2020-05-01   7314.0
# 2020-06-01   7682.0
# 2020-07-01   8298.0
# 2020-08-01   8911.0
# 2020-09-01   9494.0
# 2020-10-01  10041.0
# 2020-11-01  10477.0
# 2020-12-01  10906.0
# 2021-01-01  11046.0
# 2021-02-01  11557.0
# 2021-03-01  12439.0
# 2021-04-01  13647.0
# 2021-05-01  14532.0
# 2021-06-01  15225.0
# 2021-07-01  15765.0
# 2021-08-01  16206.0
# 2021-09-01  17076.0
# 2021-10-01  18068.0
# 2021-11-01  19004.0
# 2021-12-01  19404.0
# 2022-01-01  19613.0
# 2022-02-01  20295.0
# 2022-03-01  20683.0
# 2022-04-01  21892.0
# 2022-05-01  23129.0
# 2022-06-01  24119.0

# %%
from statsmodels.tsa.seasonal import seasonal_decompose
result = seasonal_decompose(ts["Count"], model = 'additive', period = 7)

fig = plt.figure()
fig = result.plot()
fig.set_size_inches(20,15)

# %%
import statsmodels.api as sm

fig = plt.figure(figsize = (20,8))
ax1 = fig.add_subplot(211)
fig = sm.graphics.tsa.plot_acf(ts, lags=20, ax=ax1)

# %%
from statsmodels.tsa.stattools import adfuller
result = adfuller(ts)
print("ADF Statistic : %f" % result[0])
print('p-value : %f' % result[1])
print('Critical Values : ')
for key, value in result[4].items() :
    print('\t%s : %.3f' % (key,value))
# Out:
# ADF Statistic : 3.699229
# p-value : 1.000000
# Critical Values :
# 	1% : -3.616
# 	5% : -2.941
# 	10% : -2.609

# %%
# 1차 차분
ts_diff = ts - ts.shift()
plt.figure(figsize = (22,8))
plt.plot(ts_diff)
plt.title("Differencing method")
plt.xlabel("Date")
plt.ylabel("Count")
plt.show()

# %%
# ADF 검정
result = adfuller(ts_diff[1:])
print("ADF Statistic : %f" % result[0])
print("p-value : %f" % result[1])
print("Critical Values : ")
for key, value in result[4].items():
    print('\t%s : %.3f' % (key,value))
# Out:
# ADF Statistic : -3.488325
# p-value : 0.008292
# Critical Values :
# 	1% : -3.616
# 	5% : -2.941
# 	10% : -2.609

# %%
import statsmodels.api as sm

fig = plt.figure(figsize = (20,8))
ax1 = fig.add_subplot(211)
fig = sm.graphics.tsa.plot_acf(ts_diff[1:], lags=20, ax=ax1)

# %%
# ARIMA(3,1,0) 모델 결과
import statsmodels.api as sm
from pandas import datetime
from statsmodels.tsa.arima.model import ARIMA

# fit model
model = ARIMA(ts, order=(3,1,0))
model_fit = model.fit()

# predict
start_index = datetime(2019, 1, 1)
end_index = datetime(2022, 6, 1)
forecast = model_fit.predict(start = start_index, end = end_index, typ ='levels')

# visualization
plt.figure(figsize = (22,8))
plt.plot(Hydr.Date, Hydr.Count, label = "original")
plt.plot(forecast, label = "predicted")
plt.title("Time Series Forecast")
plt.xlabel("Date")
plt.ylabel("Count")
plt.legend()
plt.show()

# %%
print(model_fit.summary())
# Out:
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                  Count   No. Observations:                   42
# Model:                 ARIMA(3, 1, 0)   Log Likelihood                -290.062
# Date:                Mon, 01 Aug 2022   AIC                            588.123
# Time:                        15:03:20   BIC                            594.977
# Sample:                    01-01-2019   HQIC                           590.619
#                          - 06-01-2022
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1          0.8465      0.175      4.842      0.000       0.504       1.189
# ar.L2         -0.0602      0.250     -0.241      0.810      -0.550       0.430
# ar.L3          0.1412      0.172      0.823      0.411      -0.195       0.478
# sigma2      7.889e+04   2.04e+04      3.866      0.000    3.89e+04    1.19e+05
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.39   Jarque-Bera (JB):                 1.62
# Prob(Q):                              0.53   Prob(JB):                         0.45
# Heteroskedasticity (H):               2.94   Skew:                             0.38
# Prob(H) (two-sided):                  0.05   Kurtosis:                         3.60
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).

# %%
# 잔차분석
resi = np.array(Hydr[Hydr.Date>=start_index].Count) - np.array(forecast)

plt.figure(figsize = (22,8))
plt.plot(Hydr.Date[Hydr.Date>=start_index],resi)

plt.xlabel("Date")
plt.ylabel("Residual")
plt.legend()
plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
result = adfuller(resi)
print("ADF Statistic : %f" % result [0])
print("p-value : %f" % result[1])
print("Critical Values : ")
for key, value in result[4].items() :
    print("\t%s : %.3f" % (key, value))
# Out:
# ADF Statistic : -4.009286
# p-value : 0.001363
# Critical Values :
# 	1% : -3.627
# 	5% : -2.946
# 	10% : -2.612

# %%
from sklearn.metrics import mean_squared_error

# fit model
forecast2 = model_fit.predict()
error = mean_squared_error(ts, forecast2)
print("error: " ,error)

# visualization
plt.figure(figsize=(22,10))
plt.plot(df.Date,df.Count,label = "original")
plt.plot(forecast2,label = "predicted")
plt.title("Time Series Forecast")
plt.xlabel("Date")
plt.ylabel("Mean Temperature")
plt.legend()
plt.savefig('graph.png')

plt.show()
# Out:
# error:  97788.87996628147

# %%
# predict
start_index = datetime(2019, 1, 1)
end_index = datetime(2025, 6, 1)
forecast = model_fit.predict(start = start_index, end = end_index, typ ='levels')

# visualization
plt.figure(figsize = (22,8))
plt.plot(df.Date, df.Count, label = "original")
plt.plot(forecast, label = "predicted")
plt.title("Time Series Forecast")
plt.xlabel("Date")
plt.ylabel("Count")
plt.legend()
plt.show()

# %%
forecast = model_fit.predict(start = datetime(2020,1,1),end = datetime(2025,1,1), typ = 'levels')
plt.figure(figsize = (22,8))
plt.plot(df.Date, df.Count, label = "original")
plt.plot(forecast, label = "predicted")
plt.title("Time Series Forecast")
plt.xlabel("Date")
plt.ylabel("Count")
plt.legend()
plt.show()
plt.show()

# %%
fore = model_fit.forecast(steps=40)
print(fore)
# Out:
# 2022-07-01    25053.290580
# 2022-08-01    25959.246112
# 2022-09-01    26809.686677
# 2022-10-01    27606.973566
# 2022-11-01    28358.607481
# 2022-12-01    29066.956780
# 2023-01-01    29733.908221
# 2023-02-01    30361.975639
# 2023-03-01    30953.507820
# 2023-04-01    31510.608087
# 2023-05-01    32035.270477
# 2023-06-01    32529.387992
# 2023-07-01    32994.740017
# 2023-08-01    33433.000415
# 2023-09-01    33845.746294
# 2023-10-01    34234.463174
# 2023-11-01    34600.549964
# 2023-12-01    34945.324110
# 2024-01-01    35270.026382
# 2024-02-01    35575.825315
# 2024-03-01    35863.821415
# 2024-04-01    36135.051115
# 2024-05-01    36390.490513
# 2024-06-01    36631.058880
# 2024-07-01    36857.621970
# 2024-08-01    37070.995134
# 2024-09-01    37271.946256
# 2024-10-01    37461.198516
# 2024-11-01    37639.432992
# 2024-12-01    37807.291111
# 2025-01-01    37965.376957
# 2025-02-01    38114.259449
# 2025-03-01    38254.474381
# 2025-04-01    38386.526357
# 2025-05-01    38510.890604
# 2025-06-01    38628.014681
# 2025-07-01    38738.320093
# 2025-08-01    38842.203805
# 2025-09-01    38940.039672
# 2025-10-01    39032.179784
# Freq: MS, Name: predicted_mean, dtype: float64
